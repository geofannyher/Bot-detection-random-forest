# %%
# Memuat data yang ingin diuji
import pandas as pd
data = pd.read_csv("hasilpreprocessing_testing.csv")

# %%
# Memuat model Random Forest Classifier
import joblib
model = joblib.load("model.pkl")

# Memprediksi label menggunakan model
prediksi = model.predict(data.drop("account_type", axis=1))

# Menghitung jumlah bot dan manusia dalam data
jumlah_label_data = data["account_type"].value_counts()
print("Jumlah bot dan manusia dalam data:")
print(jumlah_label_data)

# Menghitung jumlah bot dan manusia dalam hasil prediksi
jumlah_prediksi = pd.Series(prediksi).value_counts()
print("Jumlah bot dan manusia dalam hasil prediksi menggunakan model :")
# print(jumlah_prediksi)

# Menampilkan jumlah bot dan manusia dalam hasil prediksi
print("Jumlah bot dalam hasil prediksi:", jumlah_prediksi["bot"])
print("Jumlah manusia dalam hasil prediksi:", jumlah_prediksi["human"])

# # Menampilkan akun yang terlabel sebagai bot namun diprediksi sebagai manusia
# bot_tapi_human = data[(data["account_type"] == "bot") & (prediksi == "human")]
# print("Akun yang terlabel sebagai bot namun diprediksi sebagai manusia:")
# bot_tapi_human.head()
# Filter akun yang terlabel sebagai bot dan diprediksi sebagai manusia
bot_tapi_human = data[(data["account_type"] == "bot") & (prediksi == "human")]

# Menampilkan hasil
if not bot_tapi_human.empty:
    print("Akun yang terlabel sebagai bot namun diprediksi sebagai manusia:")
    print(bot_tapi_human)
else:
    print("Tidak ada akun yang terlabel sebagai bot dan diprediksi sebagai manusia.")
# Out:
# Jumlah bot dan manusia dalam data:
# human    201
# bot       99
# Name: account_type, dtype: int64
# Jumlah bot dan manusia dalam hasil prediksi menggunakan model :
# Jumlah bot dalam hasil prediksi: 91
# Jumlah manusia dalam hasil prediksi: 209
# Akun yang terlabel sebagai bot namun diprediksi sebagai manusia:
#      default_profile  favourites_count  followers_count  friends_count  \
# 14             False              1115          2015401          14905
# 56             False              2534              217            310
# 62              True              5456              141              2
# 69              True            571383            14645           7827
# 89             False              8015          1368076            204
# 93             False               514              948            931
# 112             True                99              228            182
# 114             True              8303             1137           4673
# 123            False               914              230            660
# 139             True             55510              478            974
# 140             True              3541               14             40
# 144            False             26939             1226            397
# 145             True             19165              330            332
# 148            False            113637           105048          79352
# 161            False             10548           184933           3759
# 162            False                75              448            382
# 181             True             54087              339            376
# 195            False             13296            22238           1119
# 230             True              5539              457            559
# 241             True              2611              464            566
# 248            False              2569              662           1511
# 256            False               135               23             38
# 267            False              4740              363           2213
# 270            False                49             3562            927
# 272            False             27349           185574          11920
# 277            False              4160              345           1748
# 280             True              1212              363           1278
# 282            False              2363               66            134
#
#                      id  location  statuses_count  verified  account_age_days  \
# 14             19923515      True          435389      True              4215
# 56            495716215      True            5199     False              3105
# 62   732736395891118083      True            6641     False              1554
# 69           2307656165      True          558538     False              2395
# 89             71225650      True          118379      True              4002
# 93           2214071510      True             676     False              2458
# 112           258478116      True            3120     False              3460
# 114          4469821522      True           12991     False              1710
# 123  920391689147244544      True             405     False              1036
# 139          3259503600      True           79189     False              1878
# 140          4112258113      True            3646     False              1750
# 144           393483438      True           47429     False              3227
# 145           537662656      True            2992     False              3067
# 148           851711263      True           70542     False              2881
# 161            47191725      True           21362      True              4083
# 162           153861776      True             462     False              3723
# 181          2331253086      True           17034     False              2385
# 195            35134309      True          109657      True              4134
# 230            69476342      True           28692     False              4009
# 241  899954647221317633      True             553     False              1092
# 248           915677660      True            7055     False              2849
# 256           132915985      True             209     False              3779
# 267            28845134      True           23718     False              4154
# 270          3383239815      True            2389     False              1857
# 272            19932359      True          123940      True              4215
# 277            14689651      True           19762     False              4486
# 280            28321195      True            3299     False              4156
# 282           264250824      True            3318     False              3448
#
#     account_type  ratio_statuses_count_per_age  ratio_favorites_per_age  \
# 14           bot                    103.295136                 0.264531
# 56           bot                      1.674396                 0.816103
# 62           bot                      4.273488                 3.510940
# 69           bot                    233.210021               238.573278
# 89           bot                     29.579960                 2.002749
# 93           bot                      0.275020                 0.209113
# 112          bot                      0.901734                 0.028613
# 114          bot                      7.597076                 4.855556
# 123          bot                      0.390927                 0.882239
# 139          bot                     42.166667                29.558040
# 140          bot                      2.083429                 2.023429
# 144          bot                     14.697552                 8.348001
# 145          bot                      0.975546                 6.248777
# 148          bot                     24.485248                39.443596
# 161          bot                      5.231937                 2.583395
# 162          bot                      0.124093                 0.020145
# 181          bot                      7.142138                22.677987
# 195          bot                     26.525641                 3.216255
# 230          bot                      7.156897                 1.381641
# 241          bot                      0.506410                 2.391026
# 248          bot                      2.476307                 0.901720
# 256          bot                      0.055306                 0.035724
# 267          bot                      5.709677                 1.141069
# 270          bot                      1.286484                 0.026387
# 272          bot                     29.404508                 6.488493
# 277          bot                      4.405261                 0.927329
# 280          bot                      0.793792                 0.291627
# 282          bot                      0.962297                 0.685325
#
#      ratio_friends_per_followers  word_count  char_count  reputation  \
# 14                      0.007396          10         120    0.992659
# 56                      1.428571          10          64    0.411765
# 62                      0.014184           8          43    0.986014
# 69                      0.534449           3          37    0.651700
# 89                      0.000149           1           1    0.999851
# 93                      0.982068          26         144    0.504524
# 112                     0.798246          24         145    0.556098
# 114                     4.109938          18         133    0.195697
# 123                     2.869565          15         102    0.258427
# 139                     2.037657           4          23    0.329201
# 140                     2.857143          16         159    0.259259
# 144                     0.323817          14          94    0.755391
# 145                     1.006061           4          24    0.498489
# 148                     0.755388          23         160    0.569675
# 161                     0.020326          16         115    0.980079
# 162                     0.852679          15         108    0.539759
# 181                     1.109145           3          15    0.474126
# 195                     0.050319          32         155    0.952091
# 230                     1.223195          16         101    0.449803
# 241                     1.219828          28         151    0.450485
# 248                     2.282477          15          77    0.304648
# 256                     1.652174           3          17    0.377049
# 267                     6.096419          15         121    0.140916
# 270                     0.260247          10          94    0.793495
# 272                     0.064233          12          72    0.939644
# 277                     5.066667          13          71    0.164835
# 280                     3.520661          18         134    0.221207
# 282                     2.030303          21         157    0.330000
#
#      contains_bot_name  description_word_count  description_character_count  \
# 14               False                       8                          111
# 56               False                      10                           55
# 62               False                       8                           36
# 69               False                       3                           35
# 89               False                       1                            1
# 93               False                      26                          119
# 112              False                      24                          122
# 114              False                      18                          116
# 123              False                      15                           88
# 139              False                       4                           20
# 140              False                      16                          144
# 144              False                      14                           81
# 145              False                       4                           21
# 148              False                      23                          138
# 161              False                      16                          100
# 162              False                      15                           94
# 181              False                       3                           13
# 195              False                      32                          124
# 230              False                      16                           86
# 241              False                      28                          124
# 248              False                      15                           63
# 256              False                       3                           15
# 267              False                      15                          107
# 270              False                      10                           85
# 272              False                      12                           61
# 277              False                      13                           59
# 280              False                      18                          117
# 282              False                      17                          125
#
#       avg_word
# 14   13.875000
# 56    5.500000
# 62    4.500000
# 69   11.666667
# 89    1.000000
# 93    4.576923
# 112   5.083333
# 114   6.444444
# 123   5.866667
# 139   5.000000
# 140   9.000000
# 144   5.785714
# 145   5.250000
# 148   6.000000
# 161   6.250000
# 162   6.266667
# 181   4.333333
# 195   3.875000
# 230   5.375000
# 241   4.428571
# 248   4.200000
# 256   5.000000
# 267   7.133333
# 270   8.500000
# 272   5.083333
# 277   4.538462
# 280   6.500000
# 282   7.352941
