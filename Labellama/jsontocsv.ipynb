# %%
import pandas as pd
import json

# %%
# dat = pd.read_csv('human_.csv',on_bad_lines='skip' )
dat = pd.read_json('human.json')
dat.head(1)
# Out:
#      id                                        annotations  \
# 0  2397  [{'id': 2222, 'completed_by': 1, 'result': [{'...
#
#                    file_upload drafts predictions  \
# 0  5d4119fc-humandsuperboy.csv     []          []
#
#                                                 data meta  \
# 0  {'Unnamed: 0': 0, 'id': 1622509979126345730, '...   {}
#
#                         created_at                       updated_at  inner_id  \
# 0 2023-02-27 07:11:57.943070+00:00 2023-02-27 07:12:01.680010+00:00         1
#
#    total_annotations  cancelled_annotations  total_predictions  comment_count  \
# 0                  1                      0                  0              0
#
#    unresolved_comment_count last_comment_updated_at  project  updated_by  \
# 0                         0                     NaT       19           1
#
#   comment_authors
# 0              []

# %%
# pd.Dataframe(dat)[['anotations', 'file_upload', 'data']].to_csv('file.csv',index=False)
# dat.to_csv('akhir.csv')
for index, row in dat.iterrows():
    kolom_array = row['annotations']
    for item in kolom_array:
        nilai = item['result']
        print(nilai)
# Out:
# [{'value': {'choices': ['Negative']}, 'id': 'OZB7sR4Y4i', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'A8hG_Cynqw', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Neutral']}, 'id': '8Ofvku4BK6', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'MQMrf79ken', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Neutral']}, 'id': '6gf-mHBNeL', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'aOCBm-5B45', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'Y6Rm03mFgU', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'WxU3cNVQgO', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'QHoUQzA0j9', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': '0uJoEdwyCU', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'C895v50vBf', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'mSEVfIwLFJ', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'H4qvqC4vTX', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'NMgDEvqZoY', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'IQ_-MFwyef', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'dWFCHNjBOH', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'wQXm97Gxe6', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'Qf5gpFTq7A', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': '6Ai9W-TQbw', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'YBpPRE1pvt', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': '55fZYI9yQq', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'WqU1ntvdAE', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': '6c56SPi4Fl', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'VHRwWO2xbg', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'x-0ohse36E', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Neutral']}, 'id': 'igxn9A88i4', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'szQgqnttaQ', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': '3QbqMpk8Y8', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'DSCybwC0jC', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': '-69CGTwYJW', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'CciIMMZMOF', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'mkWACIABLf', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'AMHpF-YqQ4', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'DYzwT2b_jm', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'dvhkxUHpJe', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'VKJ5fOvZ6W', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'pN-X7tkRQO', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'F0g7fYyrvZ', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'czsbmEti50', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'J891VPnz6s', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'vb7QKk7Gyb', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'eOOeY0-KBZ', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': '_2-O9er4u3', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'B17Gz4VXYZ', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'bVqO3f0_Rk', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'Yn5AzHW6zA', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': '7WG-BSkunp', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'mqP5ADK3xe', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'nuuwE_ZqFc', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'aWzQyee5Yo', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'hBA4YgkskH', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Neutral']}, 'id': 'kon8EuPti4', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'l6FMzt3s3a', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'nIYt6N8GTw', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': '0YDj8CvQdM', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'lC9Q9ClTfb', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'wL4js2hhZb', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'dw3x1o2ZmZ', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': '9f0t0wfxr5', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'tiJ7fEACV4', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'ilT4O5Domi', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'CHuuJM18gn', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': '_HAklFKRvN', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'j406uy8Tm0', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'ysyKMEznQG', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'g2WWVzWFb4', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'fu3tkJWCeC', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'LMM9nEOQip', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'VuL4e2NlmP', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'KSPhKDDgdd', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'KhoIVGl0Vd', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'CUgSratkwA', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'RAz5AXAvsT', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'Onterx7lMS', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'k9i1bc0VnK', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'Qpzvr15eZy', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': '3GMOsdHqk1', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'apIeiL4_ny', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'X0jlFnD3_G', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'vtzAX6BcPF', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Neutral']}, 'id': 'FXtr1GyE_j', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'Dqgy5jfolQ', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': '_o592igT1h', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'CZ61qoU-MB', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'GdHZO3T_zk', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'eCC0BMn9OP', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'TGZseF5pGx', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'MKbWj61XS7', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'C4TdsKMMT9', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': '9SXoWcKfY3', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'H7yLu7azHG', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'CnWEvs8YC4', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'VfGi3ZYgEo', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': '8mEq4sBRV9', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': '0rVsoxErZq', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'JwQmcw0Iel', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'hvMWVLhoxw', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'bpKcsv2k7c', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Neutral']}, 'id': 'ZZdIBt3phN', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'SIpJarfvHY', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': '7qXa6nrO9V', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': '8UYIL_NHyZ', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'LJDjlD0E1B', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': '7fL7ItEmK2', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'Hchx5IkLB5', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Neutral']}, 'id': 'rM0htY3FpY', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'TEtu_FJ9wC', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'QTQ_LYiT51', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'Br1ZwfXnDW', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'SOiqVxifNI', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'DrGHRHgc3J', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'Hd8wrE3RTU', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': '8VDc0ZQBdz', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': '3H26-AafnB', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'EHk8zLtiau', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'xAj7Uo_-T6', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'F4zraePyeA', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'xXFmjb9fdZ', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'eBp7KV6FjG', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'hLNpvWcDah', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': '9mA-aAmdZX', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'JWnBG2harG', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': '5nbZhTs6NT', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'PsY3Za0wf8', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'jDHZ5IZuTl', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'fszX4vnoF8', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'jRYi4zzN81', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'mNI-rWqGXd', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': '6SgsCYGEZ3', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'zYiZkGIHr0', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'S7aMb_NLTI', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Neutral']}, 'id': 'etRYExpnjP', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Neutral']}, 'id': 'helaYPV4R7', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'Fs8YaBTvzh', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': '3-DRklaBPq', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'IAixxgShtu', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'IEFMxzWQ1E', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'Ui6a_h0hgx', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': '0-7HL2XQmt', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'njGaZJrOeR', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'CJOo5m7UUi', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'cZKU33rkMB', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'PsX4SR_nGm', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Neutral']}, 'id': 'zrl__oe1Vz', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'OZo36KN_KK', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'tHoWVY29Uh', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'gJWWbOyHuX', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'd4wQJx2kTv', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'aMEBrsOrCo', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'iAJaHonxV3', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'RZWKVDCkc9', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'Fy2YMUqDnq', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': '008YrCvETB', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'gzzSiyjIqF', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': '4jiRWsFwjj', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'yDU5e3S_WI', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Neutral']}, 'id': 'MaA8QsQAQL', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'kuHzSgtWRA', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'kXV5MWs5al', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'hhS2mSGJ-C', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': '7LS0asDpUv', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'i0LAJ-gMRV', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'w5dGn0x6xV', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': '5qAo8It3pD', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'jeBfb5P0U6', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'F0ICPrdYiX', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'tyV8Vx6fP3', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': '8uNkORfhZ6', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'CMHF3NWK9H', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': '6AH7E6XO7E', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'Sl-ETAU8Ei', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'r79cCKuKaJ', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'rE2V-T1VY9', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'W7MolbUm_H', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'JL92JmG9SL', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'KWIHGkMMFp', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'AuP_K0U-bj', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'r2XEq1PV67', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'W6ZFXo-Ujo', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'MmxgScoSsU', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'cMff3QxCeM', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'ApfuJDzw2j', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': '9nVHcAXtVZ', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'tM2l2uEISu', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'Oc8WfOJxgI', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': '-sI-QFQZ3E', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'wmDSE0MuZd', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': '62dikbCnQy', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'D9tteByU_o', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'yLfP09Kasd', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Neutral']}, 'id': '9ujVnZ9v4v', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Positive']}, 'id': 'JzbfqnmG8K', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'Wk6aaA4l4U', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'pioA3iqlDk', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'L44_k3-Es4', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Neutral']}, 'id': 'l56s_xvdsL', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'ghOu8H1Cn3', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'qkYFDALpkI', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'zOkEl1Viwc', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]
# [{'value': {'choices': ['Negative']}, 'id': 'Wuyvl0sq5g', 'from_name': 'sentiment', 'to_name': 'text', 'type': 'choices', 'origin': 'manual'}]

# %%
# dat.to_csv('testi.csv',columns=[([annotations])])
# print('end')
